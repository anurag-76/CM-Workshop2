# %% [markdown]
# <a href="https://colab.research.google.com/github/anurag-76/CM-Workshops/blob/main/Workshop4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task-4
#
# ![image.png](data:image/png;base64,...)
